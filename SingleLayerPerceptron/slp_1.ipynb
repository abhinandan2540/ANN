# %%
import numpy as np
X=0.2
W=0.5
b=1
Y=1
LR=0.01

# %%
# single layer perceptron equation 
# z=w*x+b
# y_pred = sigmoid (z)
# loss (cross entropy loss (binary))
# updation of weights and bias


for _ in range(1000000):

    z=W*X+b
    Y_pred=1/(1+np.exp(-z)) # prediction (from activation function)
    loss=-(Y*np.log(Y_pred)+(1-Y)*np.log(1-Y_pred)) # binary cross entropy loss

    dloss_dw=(Y_pred - Y)*Y_pred*(1-Y_pred)*X # dloss/dw
    dloss_db=(Y_pred-Y)*Y_pred*(1-Y_pred)*1 # dloss/db

    W=W-LR*dloss_dw
    b=b-LR*dloss_db

print(f'final weight {W}')
print(f"final bias {b}")
print(Y_pred)
# Out:
# final weight 1.313582943165895
# final bias 5.0679147158299225
# 0.9951823084552521

# %% [markdown]
# the model was trained to adjust value close to y
#
# *model sucessfully did it by adjsuting it's w,b*
